# %%
import pandas as pd

# %%
daf1= pd.read_excel('E:/Eduvance/machine-learning-course/alldays_3718.xlsx')
daf1.head()
# Out:
#    OBU_ID      KMPL       RED      GREEN     YELLOW       IDLE
# 0    1240  3.398911  3.347434  41.383116  30.366011  24.682729
# 1    1241  3.327784  0.570057  21.302130  41.854185  36.123612
# 2    1246  3.123212  1.117213  33.516379  39.272865  25.979928
# 3    1251  2.582924  0.521376   6.465068  14.911366  77.997914
# 4    1252  1.956522  1.871102   3.846154   8.835759  85.446985

# %%
daf1 = daf1.dropna(subset=['KMPL','RED','GREEN','YELLOW','IDLE'])
daf1.head()
# Out:
#    OBU_ID      KMPL       RED      GREEN     YELLOW       IDLE
# 0    1240  3.398911  3.347434  41.383116  30.366011  24.682729
# 1    1241  3.327784  0.570057  21.302130  41.854185  36.123612
# 2    1246  3.123212  1.117213  33.516379  39.272865  25.979928
# 3    1251  2.582924  0.521376   6.465068  14.911366  77.997914
# 4    1252  1.956522  1.871102   3.846154   8.835759  85.446985

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.scatter(daf1['RED'],daf1['KMPL'],c='r')
plt.scatter(daf1['YELLOW'],daf1['KMPL'],c='y')
plt.scatter(daf1['GREEN'],daf1['KMPL'],c='g')

# %%
import numpy as np
x1 =daf1[['RED','GREEN','YELLOW']]
y1 = daf1['KMPL']
x1.shape
# Out:
# (71, 3)

# %%
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
x_scaler = StandardScaler()
y_scaler = StandardScaler()
x1_train = x_scaler.fit_transform(x1_train)
y1_train = y_scaler.fit_transform(y1_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-25bbbe0302cc> in <module>()
#       3 y_scaler = StandardScaler()
#       4 x1_train = x_scaler.fit_transform(x1_train)
# ----> 5 y1_train = y_scaler.fit_transform(y1_train)
#
# c:\users\anil\appdata\local\programs\python\python36\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     515         if y is None:
#     516             # fit method of arity 1 (unsupervised transformation)
# --> 517             return self.fit(X, **fit_params).transform(X)
#     518         else:
#     519             # fit method of arity 2 (supervised transformation)
#
# c:\users\anil\appdata\local\programs\python\python36\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     588         # Reset internal state before fitting
#     589         self._reset()
# ...

# %%
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.cross_validation import cross_val_score



# Create and fit the model
#model = SGDRegressor(loss="squared_loss", max_iter=100000)
poly1 = PolynomialFeatures(degree=3)
Quadratic_train = poly1.fit_transform(x1_train)

model1 = LinearRegression() 
model1.fit(Quadratic_train,y1_train)
print(model1.predict(CC))
daf1
# Out:
# [3.14145613 3.62532488 3.05115803 3.39671724 3.35232915 3.34521918
#  3.12849385 3.42654863 2.6637283  3.40185898 3.59543251 3.40621082
#  3.24720003 3.36277046 3.54837606 2.90690743 3.42492882 3.34642004
#  3.22160649 3.84747382 3.22483382 3.46675361 3.36870097 3.30181412
#  3.22689975 3.32444916 3.30354647 3.53211915 3.39796685 3.79292537
#  3.81153649 3.33786265 3.21527701 3.33373444 3.45820677 3.39676635
#  3.13353651 3.44668494 1.7390946  3.20249819 3.49001718 3.53381274
#  3.33863644 3.76724743 3.05048082 3.11200231 3.56648929 4.45117443
#  3.08055046 3.24056447 3.26496586 3.34113624 3.32294392 3.22829363
#  3.2809796  3.54746979]
#     OBU_ID      KMPL        RED      GREEN     YELLOW       IDLE
# 0     1240  3.398911   3.347434  41.383116  30.366011  24.682729
# 1     1241  3.327784   0.570057  21.302130  41.854185  36.123612
# 2     1246  3.123212   1.117213  33.516379  39.272865  25.979928
# 3     1251  2.582924   0.521376   6.465068  14.911366  77.997914
# ...

# %%
#x1_test = poly1.fit_transform(x1_test)
predicted1 = model1.predict()
from sklearn.metrics import mean_squared_error
mean_squared_error(predicted1, y1_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-d9595ed76501> in <module>()
#       2 predicted1 = model1.predict(Quadratic_train)
#       3 from sklearn.metrics import mean_squared_error
# ----> 4 mean_squared_error(predicted1, y1_test)
#
# c:\users\anil\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     236     """
#     237     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 238         y_true, y_pred, multioutput)
#     239     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#     240                                weights=sample_weight)
#
# c:\users\anil\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      73
#      74     """
# ...

# %%
model1.score(Quadratic_train,y1_train)
# Out:
# 0.5661799841493081

# %%
daf= pd.read_excel('E:/Eduvance/machine-learning-course/4th_july.xlsx','3718')
daf.head()
# Out:
#    OBU_ID      KMPL       RED      GREEN     YELLOW        IDLE
# 0    1240  2.914945  4.765146  45.677332  35.534377   13.955071
# 1    1241  3.368209  0.604396  28.846154  40.824176   29.450549
# 2    1246  3.370760  1.093840  45.077720  31.606218   22.164652
# 3    1251  1.402340  0.000000   0.000000   0.000000  100.000000
# 4    1252  2.867187  0.520833   4.166667  10.416667   84.895833

# %%
x_1=daf[['RED','GREEN','YELLOW']]
xs=poly1.fit_transform(x_1)
model1.predict(xs)
# Out:
# array([ 3.65589666,  3.35911886,  3.56455372, -2.83790774,  1.83296716,
#        -1.76196384,  3.64510221,  3.43214786,  3.76696637, -0.91483301,
#         3.45135121,  6.02141531,  3.59931391,  6.30344386,  3.39508358,
#         3.47776249,  3.24585289,  4.29846114,  2.8562307 ,  3.93962653,
#         5.36496767,  3.30043245,  3.33034739,  4.25270998, -0.0152937 ,
#         4.76225291,  3.05528158,  3.94792664,  3.77956393,  2.94139269,
#         3.49466031,  4.53084504,  3.41074021,  2.11673912,  3.6468082 ,
#         2.20347949, -1.22267449,  5.98845244,  3.5611217 ,  3.57290733,
#         2.63927673,  3.33791049,  1.40840044,  3.68259155,  3.35008846,
#         6.04459773,  4.15088238, -2.83790774,  3.08238606,  3.98008609,
#        -5.61652845,  1.91147275,  3.4823618 ,  3.76950078,  3.26278098,
#         3.7142207 ,  3.33112326,  0.75522745,  4.19568774, -1.54374505,
#         3.70645179,  3.23047945,  3.32560304,  0.35074357,  3.29577087,
# ...
